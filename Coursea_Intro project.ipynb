# %% [markdown]
# # Coursea-capstone-project

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9f3ff3a033cb> in <module>
#       1 # @hidden cells
# ----> 2 username= aungmyomin92263@gmail.com
#       3 password= 1232344
#
# NameError: name 'aungmyomin92263' is not defined

# %%
print('helloworld')
# Out:
# helloworld
